# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys
print(sys.path)
import time
# Out:
# ['', 'c:\\users\\tanmaya\\appdata\\local\\programs\\python\\python35\\python35.zip', 'c:\\users\\tanmaya\\appdata\\local\\programs\\python\\python35\\DLLs', 'c:\\users\\tanmaya\\appdata\\local\\programs\\python\\python35\\lib', 'c:\\users\\tanmaya\\appdata\\local\\programs\\python\\python35', 'c:\\users\\tanmaya\\appdata\\local\\programs\\python\\python35\\lib\\site-packages', 'c:\\users\\tanmaya\\appdata\\local\\programs\\python\\python35\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\Tanmaya\\.ipython']

# %%
df=pd.read_csv("./data/user_preprocessing/survey_results_public.csv")
print(df.describe())
print(df.head())
print(df.columns)

n_row=df.shape[0]
print(df.isnull().sum()/n_row)
attr_to_drop=[]
attr_to_drop.append("SurveyTooLong")
attr_to_drop.append('SurveyEasy')
attr_to_drop.append("AdBlocker")
attr_to_drop.append("AdBlockerDisable")
attr_to_drop.append("AdBlockerReasons")
attr_to_drop.append("AdsAgreeDisagree1")
attr_to_drop.append("AdsAgreeDisagree2")
attr_to_drop.append("AdsAgreeDisagree3")
attr_to_drop.append("AdsActions")
attr_to_drop.append("AdsPriorities1")
attr_to_drop.append("AdsPriorities2")
attr_to_drop.append("AdsPriorities3")
attr_to_drop.append("AdsPriorities4")
attr_to_drop.append("AdsPriorities5")
attr_to_drop.append("AdsPriorities6")
attr_to_drop.append("AdsPriorities7")
attr_to_drop.append("AIDangerous")
attr_to_drop.append("AIInteresting")
attr_to_drop.append("AIResponsible")
attr_to_drop.append("AIFuture")
attr_to_drop.append("EthicsChoice")
attr_to_drop.append("EthicsReport")
attr_to_drop.append("EthicsResponsible")
attr_to_drop.append("EthicsImplications")
attr_to_drop.append("EthicsChoice")
attr_to_drop.append("StackOverflowRecommend")
attr_to_drop.append("StackOverflowVisit")
attr_to_drop.append("StackOverflowHasAccount")
attr_to_drop.append("StackOverflowParticipate")
attr_to_drop.append("StackOverflowJobs")
attr_to_drop.append("StackOverflowDevStory")
attr_to_drop.append("StackOverflowJobsRecommend")
attr_to_drop.append("StackOverflowConsiderMember")
attr_to_drop.append("HypotheticalTools1")
attr_to_drop.append("HypotheticalTools2")
attr_to_drop.append("HypotheticalTools3")
attr_to_drop.append("HypotheticalTools4")
attr_to_drop.append("HypotheticalTools5")
attr_to_drop.append("JobContactPriorities1")
attr_to_drop.append("JobContactPriorities2")
attr_to_drop.append("JobContactPriorities3")
attr_to_drop.append("JobContactPriorities4")
attr_to_drop.append("JobContactPriorities5")
attr_to_drop.append("TimeAfterBootcamp")
df=df.drop(df.columns[[126,3,8,15,50,51,53,62,63,64,123,125,43,44,45,46,47,48,49]],axis=1)
print(df.columns)
df=df[df.columns.difference(attr_to_drop)]
print(df.head())
attr_to_drop=["HackathonReasons","ErgonomicDevices"]
df=df[df.columns.difference(attr_to_drop)]


print(sum(df.isnull().sum())/float(np.prod(df.shape)))
col_null=df.isnull().sum()/n_row
print(col_null.sort_values(ascending=False))
#print(sum(df.isnull().sum()))
# Out:
# c:\users\tanmaya\appdata\local\programs\python\python35\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           Respondent    AssessJob1    AssessJob2    AssessJob3    AssessJob4  \
# count   98855.000000  66985.000000  66985.000000  66985.000000  66985.000000
# mean    50822.971635      6.397089      6.673524      5.906875      4.065791
# std     29321.650410      2.788428      2.531202      2.642734      2.541196
# min         1.000000      1.000000      1.000000      1.000000      1.000000
# 25%     25443.500000      4.000000      5.000000      4.000000      2.000000
# 50%     50823.000000      7.000000      7.000000      6.000000      4.000000
# 75%     76219.500000      9.000000      9.000000      8.000000      6.000000
# max    101592.000000     10.000000     10.000000     10.000000     10.000000
#
#          AssessJob5    AssessJob6    AssessJob7    AssessJob8    AssessJob9  \
# count  66985.000000  66985.000000  66985.000000  66985.000000  66985.000000
# mean       3.953243      4.407196      5.673181      4.225200      7.640009
# std        2.520499      2.502069      2.923998      2.507411      2.407457
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        2.000000      2.000000      3.000000      2.000000      6.000000
# 50%        3.000000      4.000000      6.000000      4.000000      8.000000
# 75%        6.000000      6.000000      8.000000      6.000000     10.000000
# max       10.000000     10.000000     10.000000     10.000000     10.000000
#
#             ...        JobEmailPriorities6  JobEmailPriorities7  \
# count       ...                46213.00000         46213.000000
# mean        ...                    4.97425             4.836388
# std         ...                    1.86063             1.659844
# min         ...                    1.00000             1.000000
# 25%         ...                    4.00000             4.000000
# 50%         ...                    5.00000             5.000000
# 75%         ...                    7.00000             6.000000
# max         ...                    7.00000             7.000000
#
#        ConvertedSalary  AdsPriorities1  AdsPriorities2  AdsPriorities3  \
# count     4.770200e+04    60479.000000    60479.000000    60479.000000
# mean      9.578086e+04        2.726880        3.805784        3.340945
# std       2.023482e+05        1.881078        1.821323        1.673485
# min       0.000000e+00        1.000000        1.000000        1.000000
# 25%       2.384400e+04        1.000000        2.000000        2.000000
# 50%       5.507500e+04        2.000000        4.000000        3.000000
# 75%       9.300000e+04        4.000000        5.000000        5.000000
# max       2.000000e+06        7.000000        7.000000        7.000000
#
#        AdsPriorities4  AdsPriorities5  AdsPriorities6  AdsPriorities7
# count    60479.000000    60479.000000    60479.000000    60479.000000
# mean         3.782470        4.383604        5.138809        4.821459
# std          1.844864        1.931746        1.853249        1.874895
# min          1.000000        1.000000        1.000000        1.000000
# 25%          2.000000        3.000000        4.000000        3.000000
# 50%          4.000000        5.000000        6.000000        5.000000
# 75%          5.000000        6.000000        7.000000        7.000000
# max          7.000000        7.000000        7.000000        7.000000
#
# [8 rows x 42 columns]
#    Respondent Hobby OpenSource         Country         Student  \
# 0           1   Yes         No           Kenya              No
# 1           3   Yes        Yes  United Kingdom              No
# 2           4   Yes        Yes   United States              No
# 3           5    No         No   United States              No
# 4           7   Yes         No    South Africa  Yes, part-time
#
#            Employment                                    FormalEducation  \
# 0  Employed part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2  Employed full-time                                   Associate degree
# 3  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4  Employed full-time  Some college/university study without earning ...
#
#                                       UndergradMajor  \
# 0                          Mathematics or statistics
# 1  A natural science (ex. biology, chemistry, phy...
# 2  Computer science, computer engineering, or sof...
# 3  Computer science, computer engineering, or sof...
# 4  Computer science, computer engineering, or sof...
#
#                 CompanySize  \
# 0        20 to 99 employees
# 1  10,000 or more employees
# 2        20 to 99 employees
# 3      100 to 499 employees
# 4  10,000 or more employees
#
#                                              DevType      ...        \
# 0                               Full-stack developer      ...
# 1  Database administrator;DevOps specialist;Full-...      ...
# 2           Engineering manager;Full-stack developer      ...
# 3                               Full-stack developer      ...
# 4  Data or business analyst;Desktop or enterprise...      ...
#
#                      Exercise Gender         SexualOrientation  \
# 0        3 - 4 times per week   Male  Straight or heterosexual
# 1   Daily or almost every day   Male  Straight or heterosexual
# 2                         NaN    NaN                       NaN
# 3  I don't typically exercise   Male  Straight or heterosexual
# 4        3 - 4 times per week   Male  Straight or heterosexual
#
#                                     EducationParents  \
# 0           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2                                                NaN
# 3  Some college/university study without earning ...
# 4  Some college/university study without earning ...
#
#                   RaceEthnicity                Age Dependents  MilitaryUS  \
# 0   Black or of African descent  25 - 34 years old        Yes         NaN
# 1  White or of European descent  35 - 44 years old        Yes         NaN
# 2                           NaN                NaN        NaN         NaN
# 3  White or of European descent  35 - 44 years old         No          No
# 4  White or of European descent  18 - 24 years old        Yes         NaN
#
#                           SurveyTooLong     SurveyEasy
# 0  The survey was an appropriate length      Very easy
# 1  The survey was an appropriate length  Somewhat easy
# 2                                   NaN            NaN
# 3  The survey was an appropriate length  Somewhat easy
# 4  The survey was an appropriate length  Somewhat easy
#
# [5 rows x 129 columns]
# Index(['Respondent', 'Hobby', 'OpenSource', 'Country', 'Student', 'Employment',
#        'FormalEducation', 'UndergradMajor', 'CompanySize', 'DevType',
#        ...
#        'Exercise', 'Gender', 'SexualOrientation', 'EducationParents',
#        'RaceEthnicity', 'Age', 'Dependents', 'MilitaryUS', 'SurveyTooLong',
#        'SurveyEasy'],
#       dtype='object', length=129)
# Respondent                     0.000000
# Hobby                          0.000000
# OpenSource                     0.000000
# Country                        0.004168
# Student                        0.039998
# Employment                     0.035749
# FormalEducation                0.042001
# UndergradMajor                 0.200486
# CompanySize                    0.276405
# DevType                        0.068353
# YearsCoding                    0.050781
# YearsCodingProf                0.211947
# JobSatisfaction                0.299216
# CareerSatisfaction             0.226099
# HopeFiveYears                  0.234050
# JobSearchStatus                0.195913
# LastNewJob                     0.201973
# AssessJob1                     0.322391
# AssessJob2                     0.322391
# AssessJob3                     0.322391
# AssessJob4                     0.322391
# AssessJob5                     0.322391
# AssessJob6                     0.322391
# AssessJob7                     0.322391
# AssessJob8                     0.322391
# AssessJob9                     0.322391
# AssessJob10                    0.322391
# AssessBenefits1                0.343301
# AssessBenefits2                0.343301
# AssessBenefits3                0.343301
#                                  ...
# EthicsResponsible              0.347125
# EthicalImplications            0.298882
# StackOverflowRecommend         0.226251
# StackOverflowVisit             0.222993
# StackOverflowHasAccount        0.223196
# StackOverflowParticipate       0.334986
# StackOverflowJobs              0.238309
# StackOverflowDevStory          0.335623
# StackOverflowJobsRecommend     0.612392
# StackOverflowConsiderMember    0.231126
# HypotheticalTools1             0.291204
# HypotheticalTools2             0.291366
# HypotheticalTools3             0.291902
# HypotheticalTools4             0.292034
# HypotheticalTools5             0.291437
# WakeTime                       0.270184
# HoursComputer                  0.270315
# HoursOutside                   0.271418
# SkipMeals                      0.272207
# ErgonomicDevices               0.655475
# Exercise                       0.270568
# Gender                         0.347843
# SexualOrientation              0.395428
# EducationParents               0.374710
# RaceEthnicity                  0.418613
# Age                            0.346781
# Dependents                     0.366790
# MilitaryUS                     0.840362
# SurveyTooLong                  0.332952
# SurveyEasy                     0.333579
# Length: 129, dtype: float64
# Index(['Respondent', 'Hobby', 'OpenSource', 'Student', 'Employment',
#        'FormalEducation', 'UndergradMajor', 'DevType', 'YearsCoding',
#        'YearsCodingProf',
#        ...
#        'HoursOutside', 'SkipMeals', 'ErgonomicDevices', 'Exercise', 'Gender',
#        'SexualOrientation', 'EducationParents', 'Age', 'SurveyTooLong',
#        'SurveyEasy'],
#       dtype='object', length=110)
#                  Age  AssessBenefits1  AssessBenefits10  AssessBenefits11  \
# 0  25 - 34 years old              NaN               NaN               NaN
# 1  35 - 44 years old              1.0               2.0               8.0
# 2                NaN              NaN               NaN               NaN
# 3  35 - 44 years old              NaN               NaN               NaN
# 4  18 - 24 years old              1.0               9.0               6.0
#
#    AssessBenefits2  AssessBenefits3  AssessBenefits4  AssessBenefits5  \
# 0              NaN              NaN              NaN              NaN
# 1              5.0              3.0              7.0             10.0
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4             10.0              2.0              4.0              8.0
#
#    AssessBenefits6  AssessBenefits7       ...         \
# 0              NaN              NaN       ...
# 1              4.0             11.0       ...
# 2              NaN              NaN       ...
# 3              NaN              NaN       ...
# 4              3.0             11.0       ...
#
#                                      SelfTaughtTypes  \
# 0  The official documentation and/or standards fo...
# 1  The official documentation and/or standards fo...
# 2                                                NaN
# 3  The official documentation and/or standards fo...
# 4  The official documentation and/or standards fo...
#
#           SexualOrientation             SkipMeals         Student  \
# 0  Straight or heterosexual                 Never              No
# 1  Straight or heterosexual                 Never              No
# 2                       NaN                   NaN              No
# 3  Straight or heterosexual  3 - 4 times per week              No
# 4  Straight or heterosexual                 Never  Yes, part-time
#
#    TimeFullyProductive                                     UndergradMajor  \
# 0  One to three months                          Mathematics or statistics
# 1  One to three months  A natural science (ex. biology, chemistry, phy...
# 2                  NaN  Computer science, computer engineering, or sof...
# 3  Three to six months  Computer science, computer engineering, or sof...
# 4  Three to six months  Computer science, computer engineering, or sof...
#
#       VersionControl                WakeTime       YearsCoding  \
# 0                Git  Between 5:00 - 6:00 AM         3-5 years
# 1     Git;Subversion  Between 6:01 - 7:00 AM  30 or more years
# 2                NaN                     NaN       24-26 years
# 3                Git  Between 6:01 - 7:00 AM       18-20 years
# 4  Zip file back-ups          Before 5:00 AM         6-8 years
#
#    YearsCodingProf
# 0        3-5 years
# 1      18-20 years
# 2        6-8 years
# 3      12-14 years
# 4        0-2 years
#
# [5 rows x 68 columns]
# 0.29139955521
# ConvertedSalary            0.517455
# Salary                     0.488362
# FrameworkWorkedWith        0.477821
# TimeFullyProductive        0.475272
# FrameworkDesireNextYear    0.441424
# CommunicationTools         0.423701
# SelfTaughtTypes            0.419817
# DatabaseDesireNextYear     0.418360
# CurrencySymbol             0.406707
# Methodology                0.403358
# SexualOrientation          0.395428
# PlatformDesireNextYear     0.379364
# EducationParents           0.374710
# Gender                     0.347843
# Age                        0.346781
# AssessBenefits11           0.343311
# AssessBenefits2            0.343301
# AssessBenefits9            0.343301
# AssessBenefits10           0.343301
# AssessBenefits1            0.343301
# AssessBenefits7            0.343301
# AssessBenefits6            0.343301
# AssessBenefits5            0.343301
# AssessBenefits4            0.343301
# AssessBenefits3            0.343301
# AssessBenefits8            0.343301
# PlatformWorkedWith         0.332366
# DatabaseWorkedWith         0.329624
# AssessJob5                 0.322391
# AssessJob6                 0.322391
#                              ...
# AssessJob10                0.322391
# AssessJob1                 0.322391
# EducationTypes             0.312528
# JobSatisfaction            0.299216
# EthicalImplications        0.298882
# SkipMeals                  0.272207
# HoursOutside               0.271418
# Exercise                   0.270568
# HoursComputer              0.270315
# WakeTime                   0.270184
# CheckInCode                0.268069
# LanguageDesireNextYear     0.259076
# VersionControl             0.248414
# IDE                        0.237287
# HopeFiveYears              0.234050
# OperatingSystem            0.229386
# NumberMonitors             0.227171
# CareerSatisfaction         0.226099
# YearsCodingProf            0.211947
# LanguageWorkedWith         0.207587
# LastNewJob                 0.201973
# UndergradMajor             0.200486
# DevType                    0.068353
# YearsCoding                0.050781
# FormalEducation            0.042001
# Student                    0.039998
# Employment                 0.035749
# Hobby                      0.000000
# OpenSource                 0.000000
# Respondent                 0.000000
# Length: 66, dtype: float64

# %%
#New set of attributes to be removed
attr_to_drop=['Hobby','NumberMonitors','Salary','CheckInCode','WakeTime','TimeFullyProductive','SkipMeals','SexualOrientation','HoursOutside','Exercise','EthicalImplications','EducationParents']
print(len(df.columns))
df=df[df.columns.difference(attr_to_drop)]
print(len(df.columns))
# Out:
# 66
# 54

# %%
#df.to_csv("removed2.csv")
import numpy as np
df1 = df.replace(np.nan, '', regex=True)

# %%
#find the unique values in each categorical attribute
Frameworknextyear=list()
for value in df1["FrameworkDesireNextYear"]:
        new=value.split(';')
        for i in new:
            Frameworknextyear.append(i)
sFNY=set(Frameworknextyear)
FrameworkWorkedWith=list()
for value in df1["FrameworkWorkedWith"]:
        new=value.split(';')
        for i in new:
            FrameworkWorkedWith.append(i)
sFW=set(FrameworkWorkedWith)
PlatformDesireNextYear=list()
for value in df1["PlatformDesireNextYear"]:
        new=value.split(';')
        for i in new:
            PlatformDesireNextYear.append(i)
sPDNY=set(PlatformDesireNextYear)
PlatformWorkedWith=list()
for value in df1["PlatformWorkedWith"]:
        new=value.split(';')
        for i in new:
            PlatformWorkedWith.append(i)
sPWW=set(PlatformWorkedWith)
LanguageDesireNextYear=list()
for value in df1["LanguageDesireNextYear"]:
        new=value.split(';')
        for i in new:
            LanguageDesireNextYear.append(i)
sLDNY=set(LanguageDesireNextYear)
LanguageWorkedWith=list()
for value in df1["LanguageWorkedWith"]:
        new=value.split(';')
        for i in new:
            LanguageWorkedWith.append(i)
sLWW=set(LanguageWorkedWith)
         
CommunicationTools=list()
for value in df1["CommunicationTools"]:
        new=value.split(';')
        for i in new:
            CommunicationTools.append(i)
sCT=set(CommunicationTools)

DatabaseWorkedWith=list()
for value in df1["DatabaseWorkedWith"]:
        new=value.split(';')
        for i in new:
            DatabaseWorkedWith.append(i)
sDWW=set(DatabaseWorkedWith)

DatabaseDesireNextYear=list()
for value in df1["DatabaseDesireNextYear"]:
        new=value.split(';')
        for i in new:
            DatabaseDesireNextYear.append(i)
sDNY=set(DatabaseDesireNextYear)

DevType=list()
for value in df1["DevType"]:
        new=value.split(';')
        for i in new:
            DevType.append(i)
sDT=set(DevType)
sFNY.remove("")
sFW.remove("")
sPDNY.remove("")
sPWW.remove("")
sLDNY.remove("")
sLWW.remove("")
sCT.remove("")
sDWW.remove("")
sDNY.remove("")
sDT.remove("")
print(sFNY)
print(sFW)
print(sPDNY)
print(sPWW)
print(sLDNY)
print(sLWW)
print(sCT)
print(sDWW)
print(sDNY)
print(sDT)
combined=sFNY.union(sFW,sFNY,sPDNY,sPWW,sLDNY,sLWW,sCT,sDWW,sDNY,sDT)
print(type(combined))
all_framework=list(combined)
print(all_framework)
all_fw=pd.DataFrame(all_framework)
# Out:
# {'Xamarin', 'TensorFlow', 'Spring', 'Cordova', 'React', 'Torch/PyTorch', 'Angular', 'Node.js', 'Hadoop', 'Spark', 'Django', '.NET Core'}
# {'Xamarin', 'TensorFlow', 'Spring', 'Cordova', 'React', 'Torch/PyTorch', 'Angular', 'Node.js', 'Hadoop', 'Spark', 'Django', '.NET Core'}
# {'WordPress', 'Mac OS', 'SharePoint', 'Heroku', 'Windows Phone', 'Drupal', 'Salesforce', 'IBM Cloud or Watson', 'Serverless', 'AWS', 'Linux', 'ESP8266', 'Raspberry Pi', 'Predix', 'Android', 'Arduino', 'Firebase', 'iOS', 'Azure', 'Mainframe', 'Apple Watch or Apple TV', 'Google Home', 'Windows Desktop or Server', 'Google Cloud Platform/App Engine', 'Amazon Echo', 'Gaming console'}
# {'WordPress', 'Mac OS', 'SharePoint', 'Heroku', 'Windows Phone', 'Drupal', 'Salesforce', 'IBM Cloud or Watson', 'Serverless', 'AWS', 'Linux', 'ESP8266', 'Raspberry Pi', 'Predix', 'Android', 'Arduino', 'Firebase', 'iOS', 'Mainframe', 'Azure', 'Apple Watch or Apple TV', 'Google Home', 'Windows Desktop or Server', 'Google Cloud Platform/App Engine', 'Amazon Echo', 'Gaming console'}
# {'Python', 'C', 'Swift', 'Erlang', 'PHP', 'Assembly', 'Lua', 'Bash/Shell', 'R', 'TypeScript', 'CoffeeScript', 'Kotlin', 'Ruby', 'Scala', 'Cobol', 'Hack', 'Objective-C', 'Rust', 'SQL', 'Clojure', 'Ocaml', 'VBA', 'C++', 'HTML', 'F#', 'Groovy', 'Perl', 'JavaScript', 'Julia', 'C#', 'CSS', 'Matlab', 'Haskell', 'Go', 'Java', 'Delphi/Object Pascal', 'Visual Basic 6', 'VB.NET'}
# {'Python', 'C', 'Swift', 'Erlang', 'PHP', 'Assembly', 'Lua', 'Bash/Shell', 'R', 'TypeScript', 'CoffeeScript', 'Kotlin', 'Ruby', 'Scala', 'Cobol', 'Hack', 'Objective-C', 'Rust', 'SQL', 'Clojure', 'Ocaml', 'VBA', 'C++', 'HTML', 'F#', 'Groovy', 'Perl', 'JavaScript', 'Julia', 'C#', 'CSS', 'Matlab', 'Haskell', 'Go', 'Java', 'Delphi/Object Pascal', 'Visual Basic 6', 'VB.NET'}
# {'Slack', 'Office / productivity suite (Microsoft Office, Google Suite, etc.)', 'Jira', 'Facebook', 'Stack Overflow Enterprise', 'HipChat', 'Confluence', 'Google Hangouts/Chat', 'Other chat system (IRC, proprietary software, etc.)', 'Other wiki tool (Github, Google Sites, proprietary software, etc.)', 'Trello'}
# {'PostgreSQL', 'IBM Db2', 'Redis', 'Google BigQuery', 'Oracle', 'Amazon Redshift', 'MongoDB', 'Neo4j', 'Cassandra', 'Amazon RDS/Aurora', 'SQL Server', 'Google Cloud Storage', 'Microsoft Azure (Tables, CosmosDB, SQL, etc)', 'Apache HBase', 'MariaDB', 'Amazon DynamoDB', 'Apache Hive', 'SQLite', 'MySQL', 'Memcached', 'Elasticsearch'}
# {'PostgreSQL', 'IBM Db2', 'Redis', 'Google BigQuery', 'Oracle', 'Amazon Redshift', 'MongoDB', 'Neo4j', 'Cassandra', 'Amazon RDS/Aurora', 'SQL Server', 'Google Cloud Storage', 'Microsoft Azure (Tables, CosmosDB, SQL, etc)', 'Apache HBase', 'MariaDB', 'Amazon DynamoDB', 'Apache Hive', 'SQLite', 'MySQL', 'Memcached', 'Elasticsearch'}
# {'QA or test developer', 'Designer', 'Database administrator', 'Back-end developer', 'Data or business analyst', 'Educator or academic researcher', 'Product manager', 'Student', 'Marketing or sales professional', 'C-suite executive (CEO, CTO, etc.)', 'Mobile developer', 'Full-stack developer', 'System administrator', 'DevOps specialist', 'Front-end developer', 'Data scientist or machine learning specialist', 'Game or graphics developer', 'Embedded applications or devices developer', 'Desktop or enterprise applications developer', 'Engineering manager'}
# <class 'set'>
# ['IBM Db2', 'Python', 'Back-end developer', 'WordPress', 'SharePoint', 'C', 'Redis', 'Google BigQuery', 'PHP', 'Drupal', 'Angular', 'Hadoop', 'Lua', 'Oracle', 'Data scientist or machine learning specialist', 'IBM Cloud or Watson', 'Designer', 'TypeScript', 'Jira', 'Neo4j', 'CoffeeScript', 'Kotlin', 'Cassandra', 'React', 'Stack Overflow Enterprise', 'Ruby', 'Scala', 'Amazon RDS/Aurora', 'SQL Server', 'Predix', 'Android', 'Hack', 'Educator or academic researcher', 'Rust', 'Other chat system (IRC, proprietary software, etc.)', 'Apache HBase', 'QA or test developer', 'Ocaml', 'Xamarin', 'VBA', 'C++', 'Product manager', 'Spring', 'Student', 'Marketing or sales professional', 'C-suite executive (CEO, CTO, etc.)', 'Groovy', 'JavaScript', 'Julia', 'C#', 'Desktop or enterprise applications developer', 'Office / productivity suite (Microsoft Office, Google Suite, etc.)', 'Data or business analyst', 'Haskell', 'SQLite', 'Delphi/Object Pascal', 'Spark', 'Windows Desktop or Server', 'Memcached', 'Trello', 'Elasticsearch', 'PostgreSQL', 'TensorFlow', 'Mac OS', 'Cordova', 'Swift', 'Heroku', 'Erlang', 'Full-stack developer', 'Windows Phone', 'Assembly', 'DevOps specialist', 'Amazon Redshift', 'Salesforce', 'Bash/Shell', 'R', 'Game or graphics developer', 'Engineering manager', 'Serverless', 'AWS', 'Slack', 'MongoDB', 'Visual Basic 6', 'Linux', 'ESP8266', 'HipChat', 'Cobol', 'Raspberry Pi', 'System administrator', 'Objective-C', 'Google Cloud Storage', 'Other wiki tool (Github, Google Sites, proprietary software, etc.)', 'Arduino', 'Microsoft Azure (Tables, CosmosDB, SQL, etc)', 'SQL', 'Clojure', 'MariaDB', 'Firebase', 'Database administrator', 'Facebook', 'F#', 'HTML', 'Amazon DynamoDB', 'Google Hangouts/Chat', 'iOS', 'Embedded applications or devices developer', 'Perl', 'Front-end developer', 'Confluence', 'Azure', 'Mainframe', '.NET Core', 'Apache Hive', 'CSS', 'Apple Watch or Apple TV', 'Matlab', 'Mobile developer', 'Torch/PyTorch', 'Google Home', 'Go', 'Node.js', 'Java', 'MySQL', 'Google Cloud Platform/App Engine', 'Amazon Echo', 'VB.NET', 'Django', 'Gaming console']

# %%
all_fw.head()
print(all_fw.columns)
#all_fw.to_csv("allFrameworks.csv")
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
#converted categorical variables into numerical
from sklearn.preprocessing import LabelEncoder
print(set(df1['JobSatisfaction']))
number=LabelEncoder()
df1['CareerSatisfaction']=number.fit_transform(df1['CareerSatisfaction'])
df1['Employment']=number.fit_transform(df1['Employment'])
df1['FormalEducation']=number.fit_transform(df1['FormalEducation'])
df1['Gender']=number.fit_transform(df1['Gender'])
df1['HopeFiveYears']=number.fit_transform(df1['HopeFiveYears'])
df1['HoursComputer']=number.fit_transform(df1['HoursComputer'])
df1['JobSatisfaction']=number.fit_transform(df1['JobSatisfaction'])
df1['OpenSource']=number.fit_transform(df1['OpenSource'])
df1['OperatingSystem']=number.fit_transform(df1['OperatingSystem'])
df1['Student']=number.fit_transform(df1['Student'])
df1['UndergradMajor']=number.fit_transform(df1['UndergradMajor'])
df1['YearsCoding']=number.fit_transform(df1['YearsCoding'])
df1['YearsCodingProf']=number.fit_transform(df1['YearsCodingProf'])

#df1.to_csv("./data/user_preprocessing/categoricalconverted.csv")
# Out:
# {'Neither satisfied nor dissatisfied', '', 'Slightly satisfied', 'Extremely dissatisfied', 'Moderately dissatisfied', 'Slightly dissatisfied', 'Moderately satisfied', 'Extremely satisfied'}

# %%
#sFNY.add('Respondent')
#Create a separate dataframe based on one hot encoding for the attributes.
# Framework=pd.DataFrame(columns=sFNY)
# idx=0
# Framework.insert(loc=idx,column='Respondent', value=[0])
# #print(Framework.columns)
# print(Framework.shape[0])
# coldic=dict(zip(Framework.columns,range(0,13)))
# print(coldic)
# #print(df1.columns)
# print(df1.shape[0])
# for i in range(3):
#     Framework = Framework.append({}, ignore_index=True)
FrameworkWorkedWith = pd.DataFrame(df1['Respondent'])
for i in sFW:
    
    FrameworkWorkedWith[i]=""
PlatformWorkedWith = pd.DataFrame(df1['Respondent'])
for i in sPWW:
    print(i)
    PlatformWorkedWith[i]=""
LanguageWorkedWith = pd.DataFrame(df1['Respondent'])
for i in sLWW:
    LanguageWorkedWith[i]=""
DatabaseWorkedWith = pd.DataFrame(df1['Respondent'])
for i in sDWW:
    DatabaseWorkedWith[i]=""
DevType = pd.DataFrame(df1['Respondent'])
for i in sDT:
    DevType[i]=""
CommunicationTools = pd.DataFrame(df1['Respondent'])
for i in sCT:
    CommunicationTools[i]=""
#framework.to_csv("framework.csv")
#framework.resize=[[98855,,len(sFNY)]]
print(len(sFW))
print(len(sPWW))
# Out:
# Salesforce
# WordPress
# Firebase
# iOS
# Android
# Predix
# Mainframe
# Amazon Echo
# Azure
# IBM Cloud or Watson
# Windows Desktop or Server
# SharePoint
# Apple Watch or Apple TV
# Google Cloud Platform/App Engine
# Gaming console
# AWS
# Mac OS
# Raspberry Pi
# Heroku
# Google Home
# Serverless
# Windows Phone
# Arduino
# Linux
# Drupal
# ESP8266
# 12
# 26

# %%
# print(Framework.shape[0])
# Framework.to_csv("hello1.csv")
time_start=time.time()
coldic=dict(zip(FrameworkWorkedWith.columns,range(0,len(sFW)+1)))
print(coldic)
print(df1.head())
for i in range(98855):
    data=(df1.loc[i,'FrameworkWorkedWith']).split(';')
    if(data[0]!=""):
       # print(data)
        for value in data:
            FrameworkWorkedWith.iloc[i,coldic[value]]=1
time_end=time.time()
print(time_end-time_start)
#PlatformWorkedWith
coldic1=dict(zip(PlatformWorkedWith.columns,range(0,len(sPWW)+1)))
print(coldic1)
#print(df1.head())
for i in range(98855):
    data=(df1.loc[i,'PlatformWorkedWith']).split(';')
    if(data[0]!=""):
       # print(data)
        for value in data:
            PlatformWorkedWith.iloc[i,coldic1[value]]=1
#LanguageWorkedWith
# Out:
# {'.NET Core': 1, 'Xamarin': 2, 'TensorFlow': 3, 'Hadoop': 4, 'Django': 5, 'Spring': 6, 'Cordova': 7, 'Node.js': 8, 'React': 9, 'Angular': 10, 'Spark': 11, 'Torch/PyTorch': 12, 'Respondent': 0}
#                  Age AssessBenefits1 AssessBenefits10 AssessBenefits11  \
# 0  25 - 34 years old
# 1  35 - 44 years old               1                2                8
# 2
# 3  35 - 44 years old
# 4  18 - 24 years old               1                9                6
#
#   AssessBenefits2 AssessBenefits3 AssessBenefits4 AssessBenefits5  \
# 0
# 1               5               3               7              10
# 2
# 3
# 4              10               2               4               8
#
#   AssessBenefits6 AssessBenefits7       ...       OperatingSystem  \
# 0                                       ...                     2
# 1               4              11       ...                     2
# 2                                       ...                     0
# 3                                       ...                     4
# 4               3              11       ...                     4
#
#               PlatformDesireNextYear                 PlatformWorkedWith  \
# 0           AWS;Azure;Linux;Firebase           AWS;Azure;Linux;Firebase
# 1                              Linux                              Linux
# 2
# 3                              Azure                              Azure
# 4  Arduino;Windows Desktop or Server  Arduino;Windows Desktop or Server
#
#   Respondent                                    SelfTaughtTypes Student  \
# 0          1  The official documentation and/or standards fo...       1
# 1          3  The official documentation and/or standards fo...       1
# 2          4                                                          1
# 3          5  The official documentation and/or standards fo...       1
# 4          7  The official documentation and/or standards fo...       3
#
#   UndergradMajor     VersionControl YearsCoding YearsCodingProf
# 0             11                Git           8               8
# 1              4     Git;Subversion           9               4
# 2              7                              6              10
# 3              7                Git           4               2
# 4              7  Zip file back-ups          10               1
#
# [5 rows x 54 columns]
# 723.9798350334167
# {'Salesforce': 1, 'Gaming console': 15, 'AWS': 16, 'Mac OS': 17, 'Raspberry Pi': 18, 'Linux': 24, 'Google Cloud Platform/App Engine': 14, 'Heroku': 19, 'WordPress': 2, 'Firebase': 3, 'iOS': 4, 'Android': 5, 'Google Home': 20, 'Respondent': 0, 'Predix': 6, 'Mainframe': 7, 'Windows Phone': 22, 'Amazon Echo': 8, 'Drupal': 25, 'Azure': 9, 'Apple Watch or Apple TV': 13, 'Arduino': 23, 'IBM Cloud or Watson': 10, 'Serverless': 21, 'ESP8266': 26, 'Windows Desktop or Server': 11, 'SharePoint': 12}
# {'Erlang': 1, 'Ruby': 2, 'Delphi/Object Pascal': 3, 'Assembly': 4, 'C#': 22, 'CSS': 5, 'Perl': 9, 'Python': 7, 'Ocaml': 11, 'Kotlin': 10, 'Visual Basic 6': 24, 'TypeScript': 27, 'Rust': 37, 'Haskell': 25, 'CoffeeScript': 33, 'HTML': 32, 'PHP': 26, 'Java': 12, 'Bash/Shell': 16, 'VBA': 18, 'C++': 17, 'Respondent': 0, 'VB.NET': 29, 'R': 34, 'Matlab': 14, 'Objective-C': 19, 'Hack': 30, 'Clojure': 31, 'F#': 20, 'JavaScript': 6, 'Cobol': 23, 'Julia': 38, 'C': 13, 'Swift': 35, 'Lua': 21, 'SQL': 36, 'Scala': 28, 'Go': 15, 'Groovy': 8}
#                  Age AssessBenefits1 AssessBenefits10 AssessBenefits11  \
# 0  25 - 34 years old
# 1  35 - 44 years old               1                2                8
# 2
# 3  35 - 44 years old
# 4  18 - 24 years old               1                9                6
#
#   AssessBenefits2 AssessBenefits3 AssessBenefits4 AssessBenefits5  \
# 0
# 1               5               3               7              10
# 2
# 3
# 4              10               2               4               8
#
#   AssessBenefits6 AssessBenefits7       ...       OperatingSystem  \
# 0                                       ...                     2
# 1               4              11       ...                     2
# 2                                       ...                     0
# 3                                       ...                     4
# 4               3              11       ...                     4
#
#               PlatformDesireNextYear                 PlatformWorkedWith  \
# 0           AWS;Azure;Linux;Firebase           AWS;Azure;Linux;Firebase
# 1                              Linux                              Linux
# 2
# 3                              Azure                              Azure
# 4  Arduino;Windows Desktop or Server  Arduino;Windows Desktop or Server
#
#   Respondent                                    SelfTaughtTypes Student  \
# 0          1  The official documentation and/or standards fo...       1
# 1          3  The official documentation and/or standards fo...       1
# 2          4                                                          1
# 3          5  The official documentation and/or standards fo...       1
# 4          7  The official documentation and/or standards fo...       3
#
#   UndergradMajor     VersionControl YearsCoding YearsCodingProf
# 0             11                Git           8               8
# 1              4     Git;Subversion           9               4
# 2              7                              6              10
# 3              7                Git           4               2
# 4              7  Zip file back-ups          10               1
#
# [5 rows x 54 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-56af40e6e2aa> in <module>()
#      32        # print(data)
#      33         for value in data:
# ---> 34             LanguageWorkedWith.iloc[i,coldic[value]]=1
#      35 #DatabasesWorkedWth
#      36 coldic3=dict(zip(DatabaseWorkedWith.columns,range(0,len(sDWW)+1)))
#
# KeyError: 'JavaScript'

# %%
print(FrameworkWorkedWith.head())
print(PlatformWorkedWith.head())
# Out:
#    Respondent .NET Core Xamarin TensorFlow Hadoop Django Spring Cordova  \
# 0           1                                          1
# 1           3                                          1
# 2           4
# 3           5         1
# 4           7
#
#   Node.js React Angular Spark Torch/PyTorch
# 0             1
# 1             1
# 2
# 3             1       1
# 4
#    Respondent Salesforce WordPress Firebase iOS Android Predix Mainframe  \
# 0           1                             1
# 1           3
# 2           4
# 3           5
# 4           7
#
#   Amazon Echo Azure   ...   Mac OS Raspberry Pi Heroku Google Home Serverless  \
# 0                 1   ...
# 1                     ...
# 2                     ...
# 3                 1   ...
# 4                     ...
#
#   Windows Phone Arduino Linux Drupal ESP8266
# 0                           1
# 1                           1
# 2
# 3
# 4                     1
#
# [5 rows x 27 columns]

# %%
time_LWW=time.time()
coldic2=dict(zip(LanguageWorkedWith.columns,range(0,len(sLWW)+1)))
print(coldic2)
print(df1.head())
for i in range(98855):
    data=(df1.loc[i,'LanguageWorkedWith']).split(';')
    if(data[0]!=""):
       # print(data)
        for value in data:
            LanguageWorkedWith.iloc[i,coldic2[value]]=1
time_LWWe=time.time()
print("Language",time_LWWe-time_LWW)
print("done")
#DatabasesWorkedWth
time_DWW=time.time()
coldic3=dict(zip(DatabaseWorkedWith.columns,range(0,len(sDWW)+1)))
print(coldic3)
print(df1.head())
for i in range(98855):
    data=(df1.loc[i,'DatabaseWorkedWith']).split(';')
    if(data[0]!=""):
       # print(data)
        for value in data:
            DatabaseWorkedWith.iloc[i,coldic3[value]]=1
time_DWWe=time.time()
print("Databases",time_DWWe-time_DWW)
#DevType
#print("done")
time_DT=time.time()
coldic4=dict(zip(DevType.columns,range(0,len(sDT)+1)))
print(coldic4)
print(df1.head())
for i in range(98855):
    data=(df1.loc[i,'DevType']).split(';')
    if(data[0]!=""):
       # print(data)
        for value in data:
            DevType.iloc[i,coldic4[value]]=1
time_DTe=time.time()
print("DevType",time_DTe-time_DT)
#CommmunicationTools
coldic5=dict(zip(CommunicationTools.columns,range(0,len(sCT)+1)))
print(coldic5)
print(df1.head())
for i in range(98855):
    data=(df1.loc[i,'CommunicationTools']).split(';')
    if(data[0]!=""):
       # print(data)
        for value in data:
            CommunicationTools.iloc[i,coldic5[value]]=1
# Out:
# {'Erlang': 1, 'Ruby': 2, 'Delphi/Object Pascal': 3, 'Assembly': 4, 'C#': 22, 'CSS': 5, 'Perl': 9, 'Python': 7, 'Ocaml': 11, 'Kotlin': 10, 'Visual Basic 6': 24, 'TypeScript': 27, 'Rust': 37, 'Haskell': 25, 'CoffeeScript': 33, 'HTML': 32, 'PHP': 26, 'Java': 12, 'Bash/Shell': 16, 'VBA': 18, 'C++': 17, 'Respondent': 0, 'VB.NET': 29, 'R': 34, 'Matlab': 14, 'Objective-C': 19, 'Hack': 30, 'Clojure': 31, 'F#': 20, 'JavaScript': 6, 'Cobol': 23, 'Julia': 38, 'C': 13, 'Swift': 35, 'Lua': 21, 'SQL': 36, 'Scala': 28, 'Go': 15, 'Groovy': 8}
#                  Age AssessBenefits1 AssessBenefits10 AssessBenefits11  \
# 0  25 - 34 years old
# 1  35 - 44 years old               1                2                8
# 2
# 3  35 - 44 years old
# 4  18 - 24 years old               1                9                6
#
#   AssessBenefits2 AssessBenefits3 AssessBenefits4 AssessBenefits5  \
# 0
# 1               5               3               7              10
# 2
# 3
# 4              10               2               4               8
#
#   AssessBenefits6 AssessBenefits7       ...       OperatingSystem  \
# 0                                       ...                     2
# 1               4              11       ...                     2
# 2                                       ...                     0
# 3                                       ...                     4
# 4               3              11       ...                     4
#
#               PlatformDesireNextYear                 PlatformWorkedWith  \
# 0           AWS;Azure;Linux;Firebase           AWS;Azure;Linux;Firebase
# 1                              Linux                              Linux
# 2
# 3                              Azure                              Azure
# 4  Arduino;Windows Desktop or Server  Arduino;Windows Desktop or Server
#
#   Respondent                                    SelfTaughtTypes Student  \
# 0          1  The official documentation and/or standards fo...       1
# 1          3  The official documentation and/or standards fo...       1
# 2          4                                                          1
# 3          5  The official documentation and/or standards fo...       1
# 4          7  The official documentation and/or standards fo...       3
#
#   UndergradMajor     VersionControl YearsCoding YearsCodingProf
# 0             11                Git           8               8
# 1              4     Git;Subversion           9               4
# 2              7                              6              10
# 3              7                Git           4               2
# 4              7  Zip file back-ups          10               1
#
# [5 rows x 54 columns]
# Language 3019.860470533371
# done
# {'Redis': 1, 'Oracle': 16, 'MariaDB': 2, 'Memcached': 17, 'Elasticsearch': 3, 'SQL Server': 4, 'Amazon Redshift': 18, 'Google Cloud Storage': 5, 'Apache HBase': 19, 'PostgreSQL': 6, 'Apache Hive': 7, 'Neo4j': 8, 'Respondent': 0, 'MongoDB': 9, 'IBM Db2': 10, 'SQLite': 21, 'Amazon DynamoDB': 11, 'Amazon RDS/Aurora': 12, 'Google BigQuery': 13, 'MySQL': 14, 'Microsoft Azure (Tables, CosmosDB, SQL, etc)': 20, 'Cassandra': 15}
#                  Age AssessBenefits1 AssessBenefits10 AssessBenefits11  \
# 0  25 - 34 years old
# 1  35 - 44 years old               1                2                8
# 2
# 3  35 - 44 years old
# 4  18 - 24 years old               1                9                6
#
#   AssessBenefits2 AssessBenefits3 AssessBenefits4 AssessBenefits5  \
# 0
# 1               5               3               7              10
# 2
# 3
# 4              10               2               4               8
#
#   AssessBenefits6 AssessBenefits7       ...       OperatingSystem  \
# 0                                       ...                     2
# 1               4              11       ...                     2
# 2                                       ...                     0
# 3                                       ...                     4
# 4               3              11       ...                     4
#
#               PlatformDesireNextYear                 PlatformWorkedWith  \
# 0           AWS;Azure;Linux;Firebase           AWS;Azure;Linux;Firebase
# 1                              Linux                              Linux
# 2
# 3                              Azure                              Azure
# 4  Arduino;Windows Desktop or Server  Arduino;Windows Desktop or Server
#
#   Respondent                                    SelfTaughtTypes Student  \
# 0          1  The official documentation and/or standards fo...       1
# 1          3  The official documentation and/or standards fo...       1
# 2          4                                                          1
# 3          5  The official documentation and/or standards fo...       1
# 4          7  The official documentation and/or standards fo...       3
#
#   UndergradMajor     VersionControl YearsCoding YearsCodingProf
# 0             11                Git           8               8
# 1              4     Git;Subversion           9               4
# 2              7                              6              10
# 3              7                Git           4               2
# 4              7  Zip file back-ups          10               1
#
# [5 rows x 54 columns]
# Databases 1180.4531762599945
# {'C-suite executive (CEO, CTO, etc.)': 13, 'Engineering manager': 1, 'Designer': 3, 'QA or test developer': 2, 'Mobile developer': 4, 'System administrator': 5, 'Game or graphics developer': 6, 'Product manager': 7, 'Data or business analyst': 8, 'Educator or academic researcher': 9, 'Marketing or sales professional': 10, 'Back-end developer': 11, 'Student': 12, 'DevOps specialist': 14, 'Front-end developer': 15, 'Database administrator': 16, 'Data scientist or machine learning specialist': 17, 'Embedded applications or devices developer': 18, 'Desktop or enterprise applications developer': 19, 'Full-stack developer': 20, 'Respondent': 0}
#                  Age AssessBenefits1 AssessBenefits10 AssessBenefits11  \
# 0  25 - 34 years old
# 1  35 - 44 years old               1                2                8
# 2
# 3  35 - 44 years old
# 4  18 - 24 years old               1                9                6
#
#   AssessBenefits2 AssessBenefits3 AssessBenefits4 AssessBenefits5  \
# 0
# 1               5               3               7              10
# 2
# 3
# 4              10               2               4               8
#
#   AssessBenefits6 AssessBenefits7       ...       OperatingSystem  \
# 0                                       ...                     2
# 1               4              11       ...                     2
# 2                                       ...                     0
# 3                                       ...                     4
# 4               3              11       ...                     4
#
#               PlatformDesireNextYear                 PlatformWorkedWith  \
# 0           AWS;Azure;Linux;Firebase           AWS;Azure;Linux;Firebase
# 1                              Linux                              Linux
# 2
# 3                              Azure                              Azure
# 4  Arduino;Windows Desktop or Server  Arduino;Windows Desktop or Server
#
#   Respondent                                    SelfTaughtTypes Student  \
# 0          1  The official documentation and/or standards fo...       1
# 1          3  The official documentation and/or standards fo...       1
# 2          4                                                          1
# 3          5  The official documentation and/or standards fo...       1
# 4          7  The official documentation and/or standards fo...       3
#
#   UndergradMajor     VersionControl YearsCoding YearsCodingProf
# 0             11                Git           8               8
# 1              4     Git;Subversion           9               4
# 2              7                              6              10
# 3              7                Git           4               2
# 4              7  Zip file back-ups          10               1
#
# [5 rows x 54 columns]
# DevType 1720.2005112171173
# {'Google Hangouts/Chat': 4, 'Facebook': 2, 'Other chat system (IRC, proprietary software, etc.)': 3, 'HipChat': 5, 'Jira': 1, 'Trello': 6, 'Stack Overflow Enterprise': 7, 'Other wiki tool (Github, Google Sites, proprietary software, etc.)': 8, 'Slack': 9, 'Confluence': 10, 'Office / productivity suite (Microsoft Office, Google Suite, etc.)': 11, 'Respondent': 0}
#                  Age AssessBenefits1 AssessBenefits10 AssessBenefits11  \
# 0  25 - 34 years old
# 1  35 - 44 years old               1                2                8
# 2
# 3  35 - 44 years old
# 4  18 - 24 years old               1                9                6
#
#   AssessBenefits2 AssessBenefits3 AssessBenefits4 AssessBenefits5  \
# 0
# 1               5               3               7              10
# 2
# 3
# 4              10               2               4               8
#
#   AssessBenefits6 AssessBenefits7       ...       OperatingSystem  \
# 0                                       ...                     2
# 1               4              11       ...                     2
# 2                                       ...                     0
# 3                                       ...                     4
# 4               3              11       ...                     4
#
#               PlatformDesireNextYear                 PlatformWorkedWith  \
# 0           AWS;Azure;Linux;Firebase           AWS;Azure;Linux;Firebase
# 1                              Linux                              Linux
# 2
# 3                              Azure                              Azure
# 4  Arduino;Windows Desktop or Server  Arduino;Windows Desktop or Server
#
#   Respondent                                    SelfTaughtTypes Student  \
# 0          1  The official documentation and/or standards fo...       1
# 1          3  The official documentation and/or standards fo...       1
# 2          4                                                          1
# 3          5  The official documentation and/or standards fo...       1
# 4          7  The official documentation and/or standards fo...       3
#
#   UndergradMajor     VersionControl YearsCoding YearsCodingProf
# 0             11                Git           8               8
# 1              4     Git;Subversion           9               4
# 2              7                              6              10
# 3              7                Git           4               2
# 4              7  Zip file back-ups          10               1
#
# [5 rows x 54 columns]

# %%
# FrameworkWorkedWith.to_csv("./data/user_preprocessing/FrameworkWorkedWith.csv")
# PlatformWorkedWith.to_csv("./data/user_preprocessing/PlatformWorkedWith.csv")

# %%
# LanguageWorkedWith.to_csv("./data/user_preprocessing/LanguageWorkedWith.csv")
# DatabaseWorkedWith.to_csv("./data/user_preprocessing/DatabaseWorkedWith.csv")
# CommunicationTools.to_csv("./data/user_preprocessing/CommunicationTools.csv")
# DevType.to_csv("./data/user_preprocessing/DevType.csv")
